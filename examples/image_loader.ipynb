# %%
# %matplotlib inline
import numpy as np
from galaxy_spin_classifier import read_img
import matplotlib.pyplot as plt

# %%
plt.imshow(np.moveaxis(read_img('data/163175.jpeg'), 0, -1))

# %%
plt.imshow(np.moveaxis(read_img('data/163175.jpeg', translate=0.5, random_generator=2022), 0, -1))

# %%
plt.imshow(np.moveaxis(read_img('data/163175.jpeg', rotate=100), 0, -1))

# %%
plt.imshow(np.moveaxis(read_img('data/163175.jpeg', target_size=3), 0, -1))

# %%
plt.imshow(np.moveaxis(read_img('data/163175.jpeg', shuffle_channel=[2, 1, 0]), 0, -1))
